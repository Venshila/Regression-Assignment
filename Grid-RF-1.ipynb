# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
dataset = pd.get_dummies(dataset,drop_first=True)
dataset=dataset.astype(int)

# %%
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
dependent
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squared_error', 'absolute_error'],
                                   'max_features':['log2','sqrt'],
                                    'n_estimators':[10,100]}
                                    
              #'max_depth':3,
               #                     'max_leaf_nodes':3}
                            

grid = GridSearchCV(RandomForestRegressor(), param_grid,refit=True,cv=5, verbose = 1,n_jobs=-1) 
#grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

# %%
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': ['log2', 'sqrt'],
#                          'n_estimators': [10, 100]},
#              verbose=1)

# %%
re=grid.cv_results_
#grid_predictions=grid.predict(X_test)
print("The R_Score value for best parameter {}".format(grid.best_params_))
# Out:
# The R_Score value for best parameter {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.056298      0.004596         0.008210        0.005564
# 1       0.444991      0.016860         0.023399        0.004273
# 2       0.054708      0.004472         0.005778        0.003931
# 3       0.443794      0.006064         0.022795        0.004559
# 4       0.157987      0.004995         0.005103        0.004192
# 5       1.644291      0.384702         0.021260        0.004543
# 6       0.184263      0.040317         0.006866        0.004057
# 7       2.499296      0.277196         0.032996        0.007462
#
#   param_criterion param_max_features  param_n_estimators  \
# 0   squared_error               log2                  10
# 1   squared_error               log2                 100
# 2   squared_error               sqrt                  10
# 3   squared_error               sqrt                 100
# 4  absolute_error               log2                  10
# 5  absolute_error               log2                 100
# 6  absolute_error               sqrt                  10
# 7  absolute_error               sqrt                 100
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'max_features':...           0.840326
# 1  {'criterion': 'squared_error', 'max_features':...           0.857992
# 2  {'criterion': 'squared_error', 'max_features':...           0.836021
# 3  {'criterion': 'squared_error', 'max_features':...           0.857484
# 4  {'criterion': 'absolute_error', 'max_features'...           0.825995
# 5  {'criterion': 'absolute_error', 'max_features'...           0.857537
# 6  {'criterion': 'absolute_error', 'max_features'...           0.841493
# 7  {'criterion': 'absolute_error', 'max_features'...           0.855250
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.768009           0.841094           0.816296           0.824387
# 1           0.774322           0.850933           0.822245           0.837780
# 2           0.767229           0.857331           0.806134           0.809824
# 3           0.773536           0.855216           0.822101           0.838659
# 4           0.770620           0.847144           0.812465           0.812587
# 5           0.779111           0.858571           0.825609           0.843798
# 6           0.769508           0.828005           0.808425           0.822713
# 7           0.774805           0.853459           0.829317           0.844010
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.818022        0.026738                5
# 1         0.828654        0.029777                4
# 2         0.815308        0.030400                6
# 3         0.829399        0.030708                3
# 4         0.813762        0.025013                8
# 5         0.832925        0.029432                1
# 6         0.814029        0.024652                7
# 7         0.831368        0.029738                2

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("children:"))
sex_male_input=int(input("sex male 0 or 1:"))
smoker_yes_input=int(input("smoker yes 0 or 1:"))
# Out:
# Age: 34
# BMI: 23
# children: 4
# sex male 0 or 1: 1
# smoker yes 0 or 1: 0

# %%
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_prediction={}".format(Future_prediction))
# Out:
# Future_prediction=[10939.345]
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
